# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

df=pd.read_csv("/content/Decision_Tree_ Dataset.csv")

# %% [markdown]
# LOAN REPAYMENT PREDICTOR

# %%
df.head()
# Out:
#    INITIAL PAYMENT  LAST PAYMENT  CREDIT SCORE  HOUSE NUMBER RESULT
# 0              201         10018           250          3046    yes
# 1              205         10016           395          3044    yes
# 2              257         10129           109          3251    yes
# 3              246         10064           324          3137    yes
# 4              117         10115           496          3094    yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INITIAL PAYMENT  1000 non-null   int64
#  1   LAST PAYMENT     1000 non-null   int64
#  2   CREDIT SCORE     1000 non-null   int64
#  3   HOUSE NUMBER     1000 non-null   int64
#  4   RESULT           1000 non-null   object
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
print(len(df))
# Out:
# 1000

# %%
df.shape
# Out:
# (1000, 5)

# %%
X=df.values[:,0:4]
Y=df.values[:,4]
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=100)

clf_entropy=DecisionTreeClassifier(criterion="entropy",random_state=100,max_depth=3,min_samples_leaf=5)
clf_entropy.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
y_pred=clf_entropy.predict(X_test)
print(y_pred)
# Out:
# ['yes' 'yes' 'No' 'yes' 'No' 'yes' 'yes' 'yes' 'No' 'No' 'No' 'No' 'yes'
#  'No' 'No' 'yes' 'yes' 'No' 'yes' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No'
#  'No' 'yes' 'No' 'No' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'No' 'yes'
#  'No' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'yes' 'yes' 'No' 'No' 'yes' 'No'
#  'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'No'
#  'yes' 'yes' 'yes' 'No' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'yes' 'No'
#  'yes' 'No' 'No' 'No' 'No' 'yes' 'No' 'yes' 'No' 'yes' 'yes' 'No' 'yes'
#  'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes'
#  'yes' 'No' 'yes' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'No' 'yes'
#  'yes' 'yes' 'No' 'No' 'No' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'No'
#  'No' 'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'No' 'yes' 'yes' 'No' 'No' 'yes'
#  'yes' 'yes' 'No' 'yes' 'yes' 'yes' 'yes' 'No' 'yes' 'No' 'No' 'No' 'No'
#  'yes' 'No' 'No' 'No' 'yes' 'yes' 'No' 'yes' 'yes' 'No' 'yes' 'No' 'yes'
# ...

# %%
print("accuracy of the model is:",accuracy_score(y_pred,y_test)*100)
# Out:
# accuracy of the model is: 93.66666666666667

# %%
for i in range(len(y_pred)):
  if y_pred[i]=="yes":
    print(f"client{i}:loan will be repayed ")
  else:
    print(f"client{i}:loan will not be repayed")
# Out:
# client0:loan will be repayed
# client1:loan will be repayed
# client2:loan will not be repayed
# client3:loan will be repayed
# client4:loan will not be repayed
# client5:loan will be repayed
# client6:loan will be repayed
# client7:loan will be repayed
# client8:loan will not be repayed
# client9:loan will not be repayed
# client10:loan will not be repayed
# client11:loan will not be repayed
# client12:loan will be repayed
# client13:loan will not be repayed
# client14:loan will not be repayed
# client15:loan will be repayed
# client16:loan will be repayed
# client17:loan will not be repayed
# client18:loan will be repayed
# client19:loan will not be repayed
# client20:loan will not be repayed
# client21:loan will be repayed
# client22:loan will not be repayed
# client23:loan will be repayed
# client24:loan will be repayed
# client25:loan will not be repayed
# client26:loan will not be repayed
# client27:loan will be repayed
# client28:loan will not be repayed
# ...
